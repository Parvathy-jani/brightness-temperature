# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

# %%
data=xr.open_dataset("C:\\Users\\parva\\Time series\\2022061706.nc4")
data.values
# Out:
# <bound method Mapping.values of <xarray.Dataset>
# Dimensions:  (time: 2, lat: 551, lon: 1100)
# Coordinates:
#   * time     (time) datetime64[ns] 2022-06-17T06:00:00 2022-06-17T06:30:00.00...
#   * lat      (lat) float32 9.988 10.02 10.06 10.1 ... 29.89 29.93 29.96 30.0
#   * lon      (lon) float32 60.01 60.04 60.08 60.12 ... 99.88 99.91 99.95 99.99
# Data variables:
#     Tb       (time, lat, lon) float32 ...
# Attributes:
#     BeginDate:       2022-06-17
#     BeginTime:       06:00:00.000Z
#     EndDate:         2022-06-17
#     EndTime:         06:59:59.999Z
#     FileHeader:      StartGranuleDateTime=2022-06-17T06:00:00.000Z;\012StopGr...
#     InputPointer:    merg_2022061706_4km-pixel
#     title:           NCEP/CPC 4km Global (60N - 60S) IR Dataset
#     ProductionTime:  2022-06-19T00:20:59.326Z
#     history:         2024-05-14 11:43:53 GMT hyrax-1.16.4 https://disc2.gesdi...>

# %%
lon=data.variables['lon'][:]
lat=data.variables['lat'][:]
Tb=data.variables['Tb'][:]

# %%
lat[419]
# Out:
# <xarray.Variable ()>
# array(25.233479, dtype=float32)
# Attributes:
#     units:          degrees_north
#     standard_name:  latitude

# %%
Tb.shape
# Out:
# (2, 551, 1100)

# %%
lon[859]
# Out:
# <xarray.Variable ()>
# array(91.255066, dtype=float32)
# Attributes:
#     units:          degrees_east
#     standard_name:  longitude

# %%
# Create a contour plot highlighting the 220 K temperature
contour_levels = [220]  # Specify the temperature level to highlight

# %%
contour = plt.contour(lon,lat,Tb[1,:,:],levels=contour_levels,colors='blue')
# Label the contour line
#plt.clabel(contour, fmt='%1.0f K', inline=True)
# Manually label the contour line at 220 K
plt.text(lon[859], lat[419], '220 K', color='k', fontsize=10)
plt.title('3D Plot of Brightness Temperature(K)')
plt.xlabel('LONGITUDE')
plt.ylabel('LATITUDE')
#plt.colorbar(label="Brigtness Temperature", orientation="vertical")
# Out:
# Text(0, 0.5, 'LATITUDE')

# %%
contour = plt.contour(lon,lat,Tb[1,:,:])
plt.title('3D Plot of Brightness Temperature(K)')
plt.xlabel('LONGITUDE')
plt.ylabel('LATITUDE')
plt.colorbar(label="Brigtness Temperature", orientation="vertical")

# %%
contour = plt.contour(lon,lat,Tb[1,:,:])
plt.title('3D Plot of Brightness Temperature(K)')
plt.xlabel('LONGITUDE')
plt.ylabel('LATITUDE')
plt.colorbar(label="Brigtness Temperature", orientation="vertical") 
# Label all temperature levels
plt.clabel(contour, inline=True, fontsize=12,colors='black')
# Out:
# <a list of 28 text.Text objects>

# %%
# Adjust the font style or weight for better differentiation# Create a contour plot highlighting the 220 K temperature
contour_levels = [208,240]  # Specify the temperature level to highlight

# Define colors for labels
label_colors = ['red', 'blue']
contour = plt.contour(lon,lat,Tb[1,:,:],levels=contour_levels,colors=label_colors)
#Label the contour lines in black
clabels = plt.clabel(contour, levels=contour_levels, inline=True, fontsize=12, colors='black')

# Manually label the contour line at 220 K
plt.text(lon[835], lat[359], '208 ', color='k', fontsize=12)
plt.title('3D Plot of Brightness Temperature(K)')
plt.xlabel('LONGITUDE')
plt.ylabel('LATITUDE')
# Out:
# Text(0, 0.5, 'LATITUDE')

# %%
plt.contourf(lon,lat,Tb[1,:,:],cmap='Blues')
plt.title('3D Plot of Brightness Temperature(K)')
plt.colorbar(label="Brigtness Temperature", orientation="vertical")
